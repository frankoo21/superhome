# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('titanic-passengers.csv',sep = ';')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708   NaN        C
# 887      0    2669   7.2292   NaN        C
# 888      0  315084   8.6625   NaN        S
# 889      0  349215   7.8958   NaN        S
# 890      0  250655  26.0000   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dfs=df['Age'].fillna(df['Age'].median())
dfs
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886    14.0
# 887    22.0
# 888    30.0
# 889    28.0
# 890    19.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Cabin'].fillna('G6',inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked'].fillna('N',inplace=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.035144  0.034212 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000 -0.339898  0.083081  0.018443 -0.549500
# Age             0.034212 -0.339898  1.000000 -0.233296 -0.172482  0.096688
# SibSp          -0.057527  0.083081 -0.233296  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443 -0.172482  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500  0.096688  0.159651  0.216225  1.000000

# %%
from sklearn.preprocessing import LabelEncoder
df['Sex']=LabelEncoder().fit_transform(df['Sex'])
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.corr()
# Out:
#              PassengerId    Pclass       Sex       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.035144  0.042939  0.036847 -0.057527 -0.001652
# Pclass         -0.035144  1.000000  0.131900 -0.369226  0.083081  0.018443
# Sex             0.042939  0.131900  1.000000  0.093254 -0.114631 -0.245489
# Age             0.036847 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# SibSp          -0.057527  0.083081 -0.114631 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.018443 -0.245489 -0.189119  0.414838  1.000000
# Fare            0.012658 -0.549500 -0.182333  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Pclass      -0.549500
# Sex         -0.182333
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
d=df.corr()[["Sex","Age"]][2:4]
d
# Out:
#           Sex       Age
# Sex  1.000000  0.093254
# Age  0.093254  1.000000

# %%
b=sns.heatmap(d)

# %%
df.corr()
# Out:
#              PassengerId    Pclass       Sex       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.035144  0.042939  0.036847 -0.057527 -0.001652
# Pclass         -0.035144  1.000000  0.131900 -0.369226  0.083081  0.018443
# Sex             0.042939  0.131900  1.000000  0.093254 -0.114631 -0.245489
# Age             0.036847 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# SibSp          -0.057527  0.083081 -0.114631 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.018443 -0.245489 -0.189119  0.414838  1.000000
# Fare            0.012658 -0.549500 -0.182333  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Pclass      -0.549500
# Sex         -0.182333
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
c=d=df.corr()[["PassengerId","Pclass","Sex","Age"]][0:4]
k=sns.heatmap(c)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map(df)

# %%
df.drop('Name', axis='columns',inplace=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0            343       No       2    1  28.0      0      0      248740
# 1             76       No       3    1  25.0      0      0      348123
# 2            641       No       3    1  20.0      0      0      350050
# 3            568       No       3    0  29.0      0      4      349909
# 4            672       No       1    1  31.0      1      0  F.C. 12750
# ..           ...      ...     ...  ...   ...    ...    ...         ...
# 886           10      Yes       2    0  14.0      1      0      237736
# 887           61       No       3    1  22.0      0      0        2669
# 888          535       No       3    0  30.0      0      0      315084
# 889          102       No       3    1   NaN      0      0      349215
# 890          428      Yes       2    0  19.0      0      0      250655
#
#         Fare  Cabin Embarked
# 0    13.0000    NaN        S
# 1     7.6500  F G73        S
# ...

# %%
df1= pd.read_csv('titanic-passengers.csv',sep = ';')
df1
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df1.to_string())
# Out:
#      PassengerId Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch              Ticket      Fare            Cabin Embarked
# 0            343       No       2                                                          Collander, Mr. Erik Gustaf    male  28.00      0      0              248740   13.0000              NaN        S
# 1             76       No       3                                                             Moen, Mr. Sigurd Hansen    male  25.00      0      0              348123    7.6500            F G73        S
# 2            641       No       3                                                              Jensen, Mr. Hans Peder    male  20.00      0      0              350050    7.8542              NaN        S
# ...

# %%
for i in df1.index:
   print(df1.loc[i,'Name'].split(sep=', ')[1].split(sep='.')[0])
# Out:
# Mr
# Mr
# Mr
# Mrs
# Mr
# Mr
# Mr
# Miss
# Mr
# Mrs
# Mr
# Miss
# Mrs
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mrs
# Mr
# Mr
# Dr
# Mr
# Miss
# Mr
# Mr
# Mr
# Major
# Mrs
# Don
# Mr
# Mr
# Mr
# Miss
# Miss
# Mr
# Mr
# Miss
# Mr
# Miss
# Mr
# Master
# Dr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mrs
# Mrs
# Miss
# Miss
# Master
# Miss
# Mr
# Rev
# Mr
# Mrs
# Mrs
# Miss
# Mr
# Mrs
# Mr
# Mr
# Miss
# Mr
# Miss
# Miss
# Miss
# Mrs
# Master
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Mrs
# Mrs
# Miss
# Mrs
# Mr
# Mr
# Mr
# Miss
# Mrs
# Mr
# Mr
# Mr
# Master
# Mr
# Mr
# Mr
# Mr
# Mrs
# Miss
# Mr
# Mr
# Master
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Col
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Miss
# Mr
# Mrs
# Miss
# Mr
# Miss
# Mrs
# Miss
# Mr
# Mr
# Mr
# Mrs
# Mr
# Miss
# Mrs
# Mr
# Miss
# Mr
# Mrs
# Miss
# Mr
# Mr
# Mr
# Miss
# Master
# Mr
# Mr
# Mr
# Mrs
# Mrs
# Miss
# Master
# Miss
# Mr
# Miss
# Mrs
# Mr
# Mr
# Dr
# Mr
# ...

# %%
for i in df1.index:
                   
                         
      df.loc[i,"Title"]=df1.loc[i,'Name'].split(sep=', ')[1].split(sep='.')[0]

# %%
df
# Out:
#      PassengerId Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0            343       No       2    1  28.0      0      0      248740
# 1             76       No       3    1  25.0      0      0      348123
# 2            641       No       3    1  20.0      0      0      350050
# 3            568       No       3    0  29.0      0      4      349909
# 4            672       No       1    1  31.0      1      0  F.C. 12750
# ..           ...      ...     ...  ...   ...    ...    ...         ...
# 886           10      Yes       2    0  14.0      1      0      237736
# 887           61       No       3    1  22.0      0      0        2669
# 888          535       No       3    0  30.0      0      0      315084
# 889          102       No       3    1   NaN      0      0      349215
# 890          428      Yes       2    0  19.0      0      0      250655
#
#         Fare  Cabin Embarked Title
# 0    13.0000    NaN        S    Mr
# 1     7.6500  F G73        S    Mr
# ...

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
for i in df.index:
    df.loc[i,'Title']=Title_Dictionary[df.loc[i,'Title']]

# %%
df
# Out:
#      PassengerId Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0            343       No       2    1  28.0      0      0      248740
# 1             76       No       3    1  25.0      0      0      348123
# 2            641       No       3    1  20.0      0      0      350050
# 3            568       No       3    0  29.0      0      4      349909
# 4            672       No       1    1  31.0      1      0  F.C. 12750
# ..           ...      ...     ...  ...   ...    ...    ...         ...
# 886           10      Yes       2    0  14.0      1      0      237736
# 887           61       No       3    1  22.0      0      0        2669
# 888          535       No       3    0  30.0      0      0      315084
# 889          102       No       3    1   NaN      0      0      349215
# 890          428      Yes       2    0  19.0      0      0      250655
#
#         Fare  Cabin Embarked Title
# 0    13.0000    NaN        S   Mrs
# 1     7.6500  F G73        S   Mrs
# ...

# %%
df.Title.value_counts().sum()
# Out:
# 891

# %%
# Out:
#   File "<ipython-input-75-0529d85b7a3b>", line 1
#     print(df.loc[i,"Title"]=df1.loc[i,'Name'].split(sep=', ')[1])
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
n=np(arr)
    n.tolist()
# Out:
#   File "<ipython-input-77-54f70f0e990b>", line 3
#     def list(n)
#                ^
# SyntaxError: invalid syntax

# %%
df1.loc[755,"Name"]
# Out:
# 'Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)'
